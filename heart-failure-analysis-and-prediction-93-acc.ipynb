# %% [markdown]
# # Welcome to My Notebook!
#
# Hello and welcome! Thank you for taking the time to explore this notebook. In this notebook, I will walk you through [briefly explain the content or goal of your notebook].
#
# If you find this notebook helpful or insightful, I would truly appreciate it if you could give an upvote! Your support helps others discover useful content and motivates me to create more.

# %% [markdown]
# ## Content

# %% [markdown]
# Hello and welcome! In this notebook, I will guide you through the process of analyzing and predicting heart disease using a dataset containing key features related to heart health. The goal of this notebook is to build a machine learning model that can predict the likelihood of heart disease based on various input features such as age, blood pressure, cholesterol levels, and more.
#
# Throughout this notebook, we will:
# - Explore and preprocess the dataset
# - Perform exploratory data analysis (EDA) to uncover patterns and insights
# - Train machine learning models for heart disease prediction
# - Evaluate and fine-tune the model to improve accuracy

# %%
#imports
#data management
import pandas as pd
import numpy as np
#model selection
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
#visualization
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
#ML algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
#extra
import warnings
warnings.filterwarnings("ignore")

# %%
#load data
db = pd.read_csv("/kaggle/input/heart-failure-prediction/heart.csv")
#we will use copy of our data for visualization and analysis
db_copy = db.copy()

# %% [markdown]
# <a id =1></a>
# # Exploratory Analysis

# %%
#fist 5 samples
db.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# 5              N      0.0       Up             0
# 6              N      0.0       Up             0
# 7              N      0.0       Up             0
# 8              Y      1.5     Flat             1
# 9              N      0.0       Up             0

# %%
#info
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# <font color = #8B0000>
# As it can be seen we have no null values
# </font>

# %%
#statistic informations
db.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# <font color = #8B0000>
# We will normalize the data to get more accurate score</br>
# Normalizing means fitting our data into 0 and 1 </br>
# We will talk more about it later</br>
# </font>

# %%
#value counts of categorical features
categoricalfeatures = ["ChestPainType","RestingECG","Sex","ExerciseAngina","ST_Slope"]
for i in categoricalfeatures:
    print(db[i].value_counts())
    print("***************************")
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64
# ***************************
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64
# ***************************
# Sex
# M    725
# F    193
# Name: count, dtype: int64
# ***************************
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64
# ***************************
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64
# ***************************

# %% [markdown]
# ### İntroduction of all features

# %% [markdown]
# | Feature          | Description                                                                                   |
# |------------------|-----------------------------------------------------------------------------------------------|
# | **Age**          | Age of the patient [years]                                                                    |
# | **Sex**          | Sex of the patient [M: Male, F: Female]                                                       |
# | **ChestPainType**| Chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic] |
# | **RestingBP**    | Resting blood pressure [mm Hg]                                                                |
# | **Cholesterol**  | Serum cholesterol [mm/dl]                                                                     |
# | **FastingBS**    | Fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]                               |
# | **RestingECG**   | Resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality, LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria] |
# | **MaxHR**        | Maximum heart rate achieved [Numeric value between 60 and 202]                                |
# | **ExerciseAngina**| Exercise-induced angina [Y: Yes, N: No]                                                      |
# | **Oldpeak**      | Oldpeak = ST depression [Numeric value measured in depression]                                |
# | **ST_Slope**     | The slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]      |
# | **HeartDisease** | Output class [1: heart disease, 0: Normal]                                                   |

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### MaxHr - Age

# %%
sns.lineplot(db_copy , x = "Age" , y = "MaxHR")
plt.title("MaxHr - Age")
plt.show()

# %% [markdown]
# ###

# %% [markdown]
# <font color = red>Which means younger people have more MaxHR rate than older people</font>

# %% [markdown]
# ### RestingBP - Cholesterol

# %%
restingbp = [None if each == 0 else each for each in db_copy["RestingBP"]]
sns.lineplot(db_copy , x = restingbp , y = "Cholesterol")
plt.xlabel("Resting Blood Pressure")
plt.title("RestingBP - Cholesterol")
plt.show()

# %% [markdown]
# <font color = red>It seems restingbp has nothing to do with cholestorol</font>

# %% [markdown]
# ### RestingBP - Age

# %%
sns.lineplot(db_copy , x = restingbp , y = "Age")
plt.xlabel("Resting Blood Pressure")
plt.title("RestingBP - Age")
plt.show()

# %% [markdown]
# <font color = red>It seems that as age increases, resting blood pressure also increases.</font>

# %% [markdown]
# <a id =2></a>
# # Visualization

# %%
categoricalfeatures = ["ChestPainType","RestingECG","Sex","ExerciseAngina","ST_Slope"]
for i in categoricalfeatures:
    ax = plt.subplot(2,3,categoricalfeatures.index(i)+1)
    sns.countplot(x= db_copy[i])
    plt.tight_layout()
plt.show()

# %% [markdown]
# <font color = #8B0000>
# As it can be seen number of males is much bigger than number of females</br>
# Lets see how much these features effect HeartDisease risk
# </font>

# %% [markdown]
# ### The degree to which different categorical features contribute to heart attack risk.

# %%
#Sex
maleHeartDiseaseRate = db_copy[(db_copy["Sex"] == "M") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["Sex"] == "M"].shape[0]
femaleHeartDiseaseRate = db_copy[(db_copy["Sex"] == "F") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["Sex"] == "F"].shape[0]
#chestpaintype
ataChestPainTypeHeartDiseaseRate = db_copy[(db_copy["ChestPainType"] == "ATA") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ChestPainType"] == "ATA"].shape[0]
napChestPainTypeHeartDiseaseRate = db_copy[(db_copy["ChestPainType"] == "NAP") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ChestPainType"] == "NAP"].shape[0]
asyChestPainTypeHeartDiseaseRate = db_copy[(db_copy["ChestPainType"] == "ASY") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ChestPainType"] == "ASY"].shape[0]
taChestPainTypeHeartDiseaseRate = db_copy[(db_copy["ChestPainType"] == "TA") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ChestPainType"] == "TA"].shape[0]
#restingecg
normalRestingEcgRate = db_copy[(db_copy["RestingECG"] == "Normal") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["RestingECG"] == "Normal"].shape[0]
stRestingEcgRate = db_copy[(db_copy["RestingECG"] == "ST") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["RestingECG"] == "ST"].shape[0]
lvhRestingEcgRate = db_copy[(db_copy["RestingECG"] == "LVH") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["RestingECG"] == "LVH"].shape[0]
#ExerciseAngina
NExerciseAnginaRate = db_copy[(db_copy["ExerciseAngina"] == "N") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ExerciseAngina"] == "N"].shape[0]
YExerciseAnginaRate= db_copy[(db_copy["ExerciseAngina"] == "Y") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ExerciseAngina"] == "Y"].shape[0]
#ST_Slope
upStSlopeRate=db_copy[(db_copy["ST_Slope"] == "Up") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ST_Slope"] == "Up"].shape[0]
flatStSlopeRate=db_copy[(db_copy["ST_Slope"] == "Flat") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ST_Slope"] == "Flat"].shape[0]
downStSlopeRate=db_copy[(db_copy["ST_Slope"] == "Down") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ST_Slope"] == "Down"].shape[0]

# %%
#Visualization
#rates
genderrate = [maleHeartDiseaseRate,femaleHeartDiseaseRate]
chestpaintyperate = [ataChestPainTypeHeartDiseaseRate,napChestPainTypeHeartDiseaseRate,asyChestPainTypeHeartDiseaseRate,taChestPainTypeHeartDiseaseRate]
restingecgrate = [normalRestingEcgRate,stRestingEcgRate,lvhRestingEcgRate]
exerciseAnginarate = [NExerciseAnginaRate,YExerciseAnginaRate]
stsloperate = [upStSlopeRate,flatStSlopeRate,downStSlopeRate]
rates = [genderrate,chestpaintyperate,restingecgrate,exerciseAnginarate,stsloperate]
#labels
genderlabels = ["male", "female"]
chestpainlabels = ["ata","nap","asy","ta"]
restingecglabels = ["normal","st","lvh"]
exerciseAnginalabels = ["No" , "Yes"]
stslopelabels = ["up","flat","down"]
labels = [genderlabels,chestpainlabels,restingecglabels,exerciseAnginalabels,stslopelabels]
titles = ["Gender","Chest Pain" , "Resting ECG" , "Exercise Angina" , "ST Slope"]


for i in range(0,5):
    plt.subplot(2, 3,i+1)
    plt.title(titles[i])
    plt.pie(rates[i],labels = labels[i],autopct='%.0f%%',colors = sns.color_palette("pastel"))

# %% [markdown]
# Results:
# 1. Males have bigger change to get heart disease
# 2. Those who have Asymptomatic (asy) have bigger change to get heart disease
# 3. Resting ecg values are close to each other so we dont have to think about it
# 4. Those with exercise-induced angina are at a significantly higher risk of having heart disease.
# 5. The higher heart disease rates in the ST slope down and ST slope flat categories compared to ST slope up are likely due to the greater number of individuals with chronic conditions like ischemia or coronary artery disease (CAD), which are more common. ST slope up typically indicates acute conditions like STEMI, which are less frequent and treated quickly, leading to a lower heart disease rate in this group.

# %% [markdown]
# ### The degree to which different continuous features contribute to heart attack risk.

# %%
corrdb = db_copy.loc[:,["Age","RestingBP","Cholesterol","FastingBS","MaxHR","Oldpeak","HeartDisease"]]
sns.heatmap(corrdb.corr(),fmt = ".2f",annot = True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Visualization of most correlated features

# %% [markdown]
# ### MaxHR - Age

# %%
plt.subplot(2,1,1)
sns.set(rc={'figure.figsize':(10, 10)})
sns.lineplot(db_copy["MaxHR"])
plt.subplot(2,1,2)
sns.lineplot(db_copy["Age"])
plt.show()

# %% [markdown]
# <font color = red>As it can be seen when Age decreases MaxHr increases vice versa</font>

# %% [markdown]
# ### MaxHR - Cholesterol

# %%
cholesterol = db_copy[db_copy["Cholesterol"] !=0]["Cholesterol"]
plt.subplot(2,1,1)
sns.set(rc={'figure.figsize':(10, 5)})
sns.lineplot(db_copy["MaxHR"])
plt.subplot(2,1,2)
sns.lineplot(cholesterol)
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ##

# %%
#Split data
y_db = db.loc[:,"HeartDisease"]
db.drop("HeartDisease",inplace = True,axis = 1)
x_db = db

# %%
x_db
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0      172              N      0.0       Up
# 1      156              N      1.0     Flat
# 2       98              N      0.0       Up
# 3      108              Y      1.5     Flat
# 4      122              N      0.0       Up
# ..     ...            ...      ...      ...
# 913    132              N      1.2     Flat
# 914    141              N      3.4     Flat
# 915    115              Y      1.2     Flat
# 916    174              N      0.0     Flat
# 917    173              N      0.0       Up
#
# [918 rows x 11 columns]

# %% [markdown]
# ## Normalizing

# %% [markdown]
# > Normalizing features ensures that all variables have the same scale, improving model performance, convergence speed, and accuracy, especially for algorithms sensitive to feature magnitude differences.

# %%
featurelist = ["Age","RestingBP","Cholesterol","FastingBS","MaxHR","Oldpeak"]
for i in featurelist:
    x_db[i] = [ (each - np.min(x_db[i])) / (np.max(x_db[i])-np.min(x_db[i]))   for each in x_db[i]]

# %% [markdown]
# ## Label Encoding

# %% [markdown]
# > One-Hot Encoding is a technique that converts categorical variables into a series of binary columns, where each column represents one category, with 1 indicating the presence of that category and 0 otherwise.

# %% [markdown]
# > One-Hot Encoding converts each category into a separate binary column, while Label Encoding assigns a unique integer to each category; One-Hot Encoding is typically used for nominal data, and Label Encoding for ordinal data.

# %%
x_db = pd.get_dummies(x_db , columns = ["ChestPainType","RestingECG","Sex","ExerciseAngina","ST_Slope"],dtype = int)

# %%
#our new database
x_db
# Out:
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# 0    0.244898       0.70     0.479270        0.0  0.788732  0.295455
# 1    0.428571       0.80     0.298507        0.0  0.676056  0.409091
# 2    0.183673       0.65     0.469320        0.0  0.267606  0.295455
# 3    0.408163       0.69     0.354892        0.0  0.338028  0.465909
# 4    0.530612       0.75     0.323383        0.0  0.436620  0.295455
# ..        ...        ...          ...        ...       ...       ...
# 913  0.346939       0.55     0.437811        0.0  0.507042  0.431818
# 914  0.816327       0.72     0.320066        1.0  0.570423  0.681818
# 915  0.591837       0.65     0.217247        0.0  0.387324  0.431818
# 916  0.591837       0.65     0.391376        0.0  0.802817  0.295455
# 917  0.204082       0.69     0.290216        0.0  0.795775  0.295455
#
#      ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0                    0                  1                  0
# 1                    0                  0                  1
# 2                    0                  1                  0
# 3                    1                  0                  0
# 4                    0                  0                  1
# ..                 ...                ...                ...
# 913                  0                  0                  0
# 914                  1                  0                  0
# 915                  1                  0                  0
# 916                  0                  1                  0
# 917                  0                  0                  1
#
#      ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0                   0               0                  1              0
# 1                   0               0                  1              0
# 2                   0               0                  0              1
# 3                   0               0                  1              0
# 4                   0               0                  1              0
# ..                ...             ...                ...            ...
# 913                 1               0                  1              0
# 914                 0               0                  1              0
# 915                 0               0                  1              0
# 916                 0               1                  0              0
# 917                 0               0                  1              0
#
#      Sex_F  Sex_M  ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  \
# 0        0      1                 1                 0              0
# 1        1      0                 1                 0              0
# 2        0      1                 1                 0              0
# 3        1      0                 0                 1              0
# 4        0      1                 1                 0              0
# ..     ...    ...               ...               ...            ...
# 913      0      1                 1                 0              0
# 914      0      1                 1                 0              0
# 915      0      1                 0                 1              0
# 916      1      0                 1                 0              0
# 917      0      1                 1                 0              0
#
#      ST_Slope_Flat  ST_Slope_Up
# 0                0            1
# 1                1            0
# 2                0            1
# 3                1            0
# 4                0            1
# ..             ...          ...
# 913              1            0
# 914              1            0
# 915              1            0
# 916              1            0
# 917              0            1
#
# [918 rows x 20 columns]

# %% [markdown]
# # Prediction

# %% [markdown]
# ## Prediction with supervised learning algorithms

# %%
#train-test split
x_train , x_test , y_train , y_test = train_test_split(x_db , y_db)

# %%
#with train-test split
logreg = LogisticRegression()
gaussiannb = GaussianNB()
dectree = DecisionTreeClassifier()
randomforest = RandomForestClassifier()
svm = SVC()
knearest = KNeighborsClassifier()
labelList = ["LogReg : " , "GaussianNb : " , "DecTree : ","RandomForest : ","Svm : " , "knearest : "]
classifierList = [logreg , gaussiannb , dectree , randomforest , svm,knearest]
for i in range(0,6):
    classifier = classifierList[i]
    classifier.fit(x_train , y_train)
    print("Score of" ,labelList[i] , classifier.score(x_test,y_test))
# Out:
# Score of LogReg :  0.9043478260869565
# Score of GaussianNb :  0.8695652173913043
# Score of DecTree :  0.8391304347826087
# Score of RandomForest :  0.8826086956521739
# Score of Svm :  0.8869565217391304
# Score of knearest :  0.8739130434782608

# %% [markdown]
# Actually these scores are going to decrease when working with real data

# %%
#Cross validation
logreg = LogisticRegression()
gaussiannb = GaussianNB()
dectree = DecisionTreeClassifier()
randomforest = RandomForestClassifier()
svm = SVC()
knearest = KNeighborsClassifier()
labelList = ["LogReg : " , "GaussianNb : " , "DecTree : ","RandomForest : ","Svm : ", "knearest : "]
classifierList = [logreg , gaussiannb , dectree , randomforest , svm,knearest]
for i in range(0,6):
    classifier = classifierList[i]
    classifier.fit(x_train , y_train)
    scores = cross_val_score(classifier, x_train , y_train,n_jobs = 5)
    print("Score of" ,labelList[i] , np.mean(scores))
# Out:
# Score of LogReg :  0.8516767163863325
# Score of GaussianNb :  0.8487675870094151
# Score of DecTree :  0.795144398603618
# Score of RandomForest :  0.8560880143869671
# Score of Svm :  0.8633555485031208
# Score of knearest :  0.8328361366761874

# %% [markdown]
# As it can be seen cross-validation-score are lower than train-test split score

# %%
#HyperParameterTuning
params = [
    
     {
         #logisticregression
        "C" : [0.01 , 0.1 , 1 , 10 , 100],
        "max_iter" : [100 , 150 , 200],
        "penalty" : ["l1" , "l2"],
        "solver" : ["lbfgs", "liblinear", "newton-cg"],
    },
    
    {
        #decisiontree
        "min_samples_leaf" : [1 , 5 , 10],
        "min_samples_split" : [3 , 5 , 10 , 20],
        "criterion" : ["gini" , "entropy"],
        },
    {
        #randomforest
    # cause it takes too much time to try all the different parameter options I used the 
    # most accurate parameters that I found
       'criterion': ['entropy'],
         'min_samples_split': [20],
         'n_estimators': [50],
        
    },
    #naive - bayes
    {
        "var_smoothing" : [1e-9 , 1e-8 , 1e-7]
    } ,
    #knearest
    {
        "n_neighbors":[3,5,10,20,30],
    "weights":["uniform","distance"],
    "metric":["eucladian","manhattan"],
    },
#svc
{
                    "C":[1,10,50,300,500],
                  "gamma":[0.1,0.01,0.001,0.0001,1],
    
},
]

# %%
X_train,X_val,Y_train,Y_val = train_test_split(x_train,y_train)
logreg = LogisticRegression()
dectree = DecisionTreeClassifier()
randforest = RandomForestClassifier()
gaussiannb = GaussianNB()
knearest = KNeighborsClassifier()
svc = SVC()
modellist = {
   'logreg': logreg,
 'dectree': dectree,
 'randforest': randforest,
 'gaussiannb': gaussiannb,
 'knearest': knearest,
 'svc': svc,}
i = 0
for key , value in modellist.items():
   clf = GridSearchCV(value , params[i])
   clf.fit(X_train,Y_train)
   print(key,": ", clf.score(X_val,Y_val)) 
   i+=1
# Out:
# logreg :  0.9244186046511628
# dectree :  0.8430232558139535
# randforest :  0.9069767441860465
# gaussiannb :  0.877906976744186
# knearest :  0.8953488372093024
# svc :  0.9186046511627907

# %% [markdown]
# <font color ="blue">
# First of all we split our train data to second train data and validation data </br>
# we used validation data as test data to find best parameters
# </font>

# %% [markdown]
# Sklearn cross validation doc: https://scikit-learn.org/1.5/modules/cross_validation.html

# %% [markdown]
# <font color = "blue">
# Cross validation score of our models with real test data
# </font>

# %%
i = 0
for key , value in modellist.items():
   clf = GridSearchCV(value , params[i])
   clf.fit(X_train,Y_train)
   print(key,": ", clf.score(x_test,y_test)) 
   i+=1
# Out:
# logreg :  0.9
# dectree :  0.8434782608695652
# randforest :  0.8956521739130435
# gaussiannb :  0.8608695652173913
# knearest :  0.8739130434782608
# svc :  0.8956521739130435

# %% [markdown]
# ## Prediction with artifical neural networks

# %% [markdown]
# <font color = "blue">We are gonna use keras </br> Keras Documents : https://keras.io/api/ </font>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam
model = Sequential()
model.add(Input(shape = (20,))) #we have 20 features thats why our input layer has 20 neurons
model.add(Dense(activation = "relu" , units = 32))
model.add(Dense(activation = "relu" , units = 32))
model.add(Dense(activation = "relu" , units = 8))
model.add(Dense(activation = "softmax" , units = 2))
model.compile(metrics = ["accuracy"] , optimizer = Adam(learning_rate = 0.0001) , loss = "sparse_categorical_crossentropy")
our_model = model.fit(x = x_train , y = y_train , batch_size = 30 , epochs = 1000 ,shuffle = True , verbose = 2,validation_data=(x_test, y_test))
# Out:
# Epoch 1/1000
# 23/23 - 2s - 76ms/step - accuracy: 0.4971 - loss: 0.6962 - val_accuracy: 0.4696 - val_loss: 0.7065
# Epoch 2/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.5509 - loss: 0.6734 - val_accuracy: 0.5522 - val_loss: 0.6805
# Epoch 3/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.5916 - loss: 0.6543 - val_accuracy: 0.5609 - val_loss: 0.6585
# Epoch 4/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.6119 - loss: 0.6374 - val_accuracy: 0.6087 - val_loss: 0.6384
# Epoch 5/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.6613 - loss: 0.6215 - val_accuracy: 0.6870 - val_loss: 0.6185
# Epoch 6/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.7456 - loss: 0.6060 - val_accuracy: 0.7870 - val_loss: 0.5980
# Epoch 7/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.7892 - loss: 0.5906 - val_accuracy: 0.8217 - val_loss: 0.5782
# Epoch 8/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8067 - loss: 0.5753 - val_accuracy: 0.8348 - val_loss: 0.5596
# Epoch 9/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8154 - loss: 0.5612 - val_accuracy: 0.8478 - val_loss: 0.5395
# Epoch 10/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8299 - loss: 0.5464 - val_accuracy: 0.8478 - val_loss: 0.5229
# Epoch 11/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8285 - loss: 0.5329 - val_accuracy: 0.8609 - val_loss: 0.5055
# Epoch 12/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8343 - loss: 0.5198 - val_accuracy: 0.8609 - val_loss: 0.4878
# Epoch 13/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8343 - loss: 0.5063 - val_accuracy: 0.8652 - val_loss: 0.4726
# Epoch 14/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8328 - loss: 0.4934 - val_accuracy: 0.8652 - val_loss: 0.4576
# Epoch 15/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8343 - loss: 0.4807 - val_accuracy: 0.8652 - val_loss: 0.4423
# Epoch 16/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8387 - loss: 0.4688 - val_accuracy: 0.8652 - val_loss: 0.4291
# Epoch 17/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8445 - loss: 0.4581 - val_accuracy: 0.8696 - val_loss: 0.4159
# Epoch 18/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8459 - loss: 0.4476 - val_accuracy: 0.8696 - val_loss: 0.4053
# Epoch 19/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8503 - loss: 0.4380 - val_accuracy: 0.8696 - val_loss: 0.3935
# Epoch 20/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8576 - loss: 0.4284 - val_accuracy: 0.8696 - val_loss: 0.3838
# Epoch 21/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8590 - loss: 0.4201 - val_accuracy: 0.8696 - val_loss: 0.3739
# Epoch 22/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8619 - loss: 0.4119 - val_accuracy: 0.8783 - val_loss: 0.3651
# Epoch 23/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.4048 - val_accuracy: 0.8826 - val_loss: 0.3576
# Epoch 24/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8663 - loss: 0.3978 - val_accuracy: 0.8870 - val_loss: 0.3504
# Epoch 25/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3917 - val_accuracy: 0.8870 - val_loss: 0.3438
# Epoch 26/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8663 - loss: 0.3864 - val_accuracy: 0.8913 - val_loss: 0.3378
# Epoch 27/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3811 - val_accuracy: 0.8913 - val_loss: 0.3331
# Epoch 28/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3772 - val_accuracy: 0.8913 - val_loss: 0.3295
# Epoch 29/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3731 - val_accuracy: 0.8913 - val_loss: 0.3239
# Epoch 30/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3692 - val_accuracy: 0.8913 - val_loss: 0.3214
# Epoch 31/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3659 - val_accuracy: 0.8913 - val_loss: 0.3169
# Epoch 32/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3629 - val_accuracy: 0.8913 - val_loss: 0.3148
# Epoch 33/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3603 - val_accuracy: 0.8913 - val_loss: 0.3117
# Epoch 34/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3580 - val_accuracy: 0.8913 - val_loss: 0.3099
# Epoch 35/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3557 - val_accuracy: 0.8913 - val_loss: 0.3076
# Epoch 36/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3539 - val_accuracy: 0.8913 - val_loss: 0.3051
# Epoch 37/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3523 - val_accuracy: 0.8913 - val_loss: 0.3055
# Epoch 38/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3504 - val_accuracy: 0.8913 - val_loss: 0.3028
# Epoch 39/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8634 - loss: 0.3489 - val_accuracy: 0.8913 - val_loss: 0.3003
# Epoch 40/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8619 - loss: 0.3480 - val_accuracy: 0.8913 - val_loss: 0.2985
# Epoch 41/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8634 - loss: 0.3466 - val_accuracy: 0.8913 - val_loss: 0.2986
# Epoch 42/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3455 - val_accuracy: 0.8913 - val_loss: 0.2989
# Epoch 43/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8605 - loss: 0.3441 - val_accuracy: 0.8913 - val_loss: 0.2973
# Epoch 44/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8605 - loss: 0.3434 - val_accuracy: 0.8913 - val_loss: 0.2947
# Epoch 45/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8605 - loss: 0.3425 - val_accuracy: 0.8913 - val_loss: 0.2966
# Epoch 46/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8634 - loss: 0.3416 - val_accuracy: 0.8913 - val_loss: 0.2936
# Epoch 47/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8634 - loss: 0.3404 - val_accuracy: 0.8913 - val_loss: 0.2932
# Epoch 48/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8605 - loss: 0.3395 - val_accuracy: 0.8913 - val_loss: 0.2939
# Epoch 49/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8619 - loss: 0.3391 - val_accuracy: 0.8913 - val_loss: 0.2947
# Epoch 50/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8619 - loss: 0.3378 - val_accuracy: 0.8913 - val_loss: 0.2924
# Epoch 51/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8619 - loss: 0.3371 - val_accuracy: 0.8913 - val_loss: 0.2921
# Epoch 52/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8619 - loss: 0.3368 - val_accuracy: 0.8913 - val_loss: 0.2928
# Epoch 53/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3362 - val_accuracy: 0.8913 - val_loss: 0.2907
# Epoch 54/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8634 - loss: 0.3354 - val_accuracy: 0.8913 - val_loss: 0.2914
# Epoch 55/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8634 - loss: 0.3348 - val_accuracy: 0.8913 - val_loss: 0.2911
# Epoch 56/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8634 - loss: 0.3342 - val_accuracy: 0.8870 - val_loss: 0.2916
# Epoch 57/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3335 - val_accuracy: 0.8870 - val_loss: 0.2909
# Epoch 58/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3331 - val_accuracy: 0.8913 - val_loss: 0.2913
# Epoch 59/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3326 - val_accuracy: 0.8870 - val_loss: 0.2902
# Epoch 60/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3321 - val_accuracy: 0.8913 - val_loss: 0.2907
# Epoch 61/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3314 - val_accuracy: 0.8913 - val_loss: 0.2905
# Epoch 62/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3311 - val_accuracy: 0.8913 - val_loss: 0.2899
# Epoch 63/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8663 - loss: 0.3305 - val_accuracy: 0.8870 - val_loss: 0.2888
# Epoch 64/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3300 - val_accuracy: 0.8870 - val_loss: 0.2887
# Epoch 65/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8663 - loss: 0.3296 - val_accuracy: 0.8913 - val_loss: 0.2896
# Epoch 66/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3290 - val_accuracy: 0.8913 - val_loss: 0.2895
# Epoch 67/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3286 - val_accuracy: 0.8870 - val_loss: 0.2882
# Epoch 68/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3283 - val_accuracy: 0.8913 - val_loss: 0.2884
# Epoch 69/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3279 - val_accuracy: 0.8870 - val_loss: 0.2877
# Epoch 70/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8648 - loss: 0.3277 - val_accuracy: 0.8870 - val_loss: 0.2880
# Epoch 71/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3269 - val_accuracy: 0.8870 - val_loss: 0.2875
# Epoch 72/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3267 - val_accuracy: 0.8870 - val_loss: 0.2875
# Epoch 73/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3263 - val_accuracy: 0.8913 - val_loss: 0.2889
# Epoch 74/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3258 - val_accuracy: 0.8870 - val_loss: 0.2868
# Epoch 75/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3254 - val_accuracy: 0.8870 - val_loss: 0.2868
# Epoch 76/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3255 - val_accuracy: 0.8870 - val_loss: 0.2874
# Epoch 77/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3248 - val_accuracy: 0.8913 - val_loss: 0.2880
# Epoch 78/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8692 - loss: 0.3248 - val_accuracy: 0.8913 - val_loss: 0.2886
# Epoch 79/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3243 - val_accuracy: 0.8870 - val_loss: 0.2865
# Epoch 80/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3239 - val_accuracy: 0.8913 - val_loss: 0.2882
# Epoch 81/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3232 - val_accuracy: 0.8913 - val_loss: 0.2867
# Epoch 82/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3231 - val_accuracy: 0.8913 - val_loss: 0.2875
# Epoch 83/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3227 - val_accuracy: 0.8870 - val_loss: 0.2857
# Epoch 84/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3225 - val_accuracy: 0.8913 - val_loss: 0.2868
# Epoch 85/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3220 - val_accuracy: 0.8870 - val_loss: 0.2863
# Epoch 86/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3217 - val_accuracy: 0.8913 - val_loss: 0.2869
# Epoch 87/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3215 - val_accuracy: 0.8870 - val_loss: 0.2858
# Epoch 88/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3216 - val_accuracy: 0.8913 - val_loss: 0.2879
# Epoch 89/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8677 - loss: 0.3210 - val_accuracy: 0.8870 - val_loss: 0.2866
# Epoch 90/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3210 - val_accuracy: 0.8870 - val_loss: 0.2843
# Epoch 91/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3202 - val_accuracy: 0.8913 - val_loss: 0.2872
# Epoch 92/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3198 - val_accuracy: 0.8913 - val_loss: 0.2873
# Epoch 93/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3195 - val_accuracy: 0.8913 - val_loss: 0.2872
# Epoch 94/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3193 - val_accuracy: 0.8870 - val_loss: 0.2857
# Epoch 95/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3192 - val_accuracy: 0.8870 - val_loss: 0.2854
# Epoch 96/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8721 - loss: 0.3188 - val_accuracy: 0.8913 - val_loss: 0.2881
# Epoch 97/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3183 - val_accuracy: 0.8913 - val_loss: 0.2868
# Epoch 98/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3180 - val_accuracy: 0.8913 - val_loss: 0.2874
# Epoch 99/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3177 - val_accuracy: 0.8870 - val_loss: 0.2864
# Epoch 100/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3175 - val_accuracy: 0.8913 - val_loss: 0.2865
# Epoch 101/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3172 - val_accuracy: 0.8913 - val_loss: 0.2868
# Epoch 102/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8706 - loss: 0.3168 - val_accuracy: 0.8913 - val_loss: 0.2862
# Epoch 103/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8721 - loss: 0.3170 - val_accuracy: 0.8913 - val_loss: 0.2876
# Epoch 104/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8721 - loss: 0.3167 - val_accuracy: 0.8913 - val_loss: 0.2865
# Epoch 105/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8721 - loss: 0.3162 - val_accuracy: 0.8870 - val_loss: 0.2860
# Epoch 106/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8692 - loss: 0.3158 - val_accuracy: 0.8913 - val_loss: 0.2869
# Epoch 107/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8721 - loss: 0.3154 - val_accuracy: 0.8913 - val_loss: 0.2869
# Epoch 108/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8721 - loss: 0.3150 - val_accuracy: 0.8913 - val_loss: 0.2865
# Epoch 109/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3154 - val_accuracy: 0.8913 - val_loss: 0.2871
# Epoch 110/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3147 - val_accuracy: 0.8913 - val_loss: 0.2876
# Epoch 111/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8735 - loss: 0.3143 - val_accuracy: 0.8913 - val_loss: 0.2858
# Epoch 112/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8735 - loss: 0.3141 - val_accuracy: 0.8913 - val_loss: 0.2861
# Epoch 113/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8735 - loss: 0.3139 - val_accuracy: 0.8913 - val_loss: 0.2871
# Epoch 114/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8735 - loss: 0.3135 - val_accuracy: 0.8870 - val_loss: 0.2853
# Epoch 115/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3132 - val_accuracy: 0.8870 - val_loss: 0.2863
# Epoch 116/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3128 - val_accuracy: 0.8913 - val_loss: 0.2870
# Epoch 117/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3127 - val_accuracy: 0.8870 - val_loss: 0.2858
# Epoch 118/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3124 - val_accuracy: 0.8870 - val_loss: 0.2858
# Epoch 119/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3120 - val_accuracy: 0.8913 - val_loss: 0.2863
# Epoch 120/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3117 - val_accuracy: 0.8870 - val_loss: 0.2867
# Epoch 121/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3115 - val_accuracy: 0.8957 - val_loss: 0.2877
# Epoch 122/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3114 - val_accuracy: 0.8957 - val_loss: 0.2869
# Epoch 123/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3110 - val_accuracy: 0.8913 - val_loss: 0.2871
# Epoch 124/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3110 - val_accuracy: 0.9000 - val_loss: 0.2886
# Epoch 125/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3102 - val_accuracy: 0.8870 - val_loss: 0.2855
# Epoch 126/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3100 - val_accuracy: 0.8913 - val_loss: 0.2868
# Epoch 127/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3100 - val_accuracy: 0.8913 - val_loss: 0.2855
# Epoch 128/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3094 - val_accuracy: 0.8957 - val_loss: 0.2870
# Epoch 129/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3094 - val_accuracy: 0.8913 - val_loss: 0.2868
# Epoch 130/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3093 - val_accuracy: 0.9000 - val_loss: 0.2888
# Epoch 131/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3088 - val_accuracy: 0.9000 - val_loss: 0.2880
# Epoch 132/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3089 - val_accuracy: 0.8957 - val_loss: 0.2873
# Epoch 133/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3082 - val_accuracy: 0.8913 - val_loss: 0.2863
# Epoch 134/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3082 - val_accuracy: 0.9000 - val_loss: 0.2885
# Epoch 135/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.3076 - val_accuracy: 0.8957 - val_loss: 0.2876
# Epoch 136/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3073 - val_accuracy: 0.8913 - val_loss: 0.2868
# Epoch 137/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8735 - loss: 0.3073 - val_accuracy: 0.9000 - val_loss: 0.2871
# Epoch 138/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3067 - val_accuracy: 0.9000 - val_loss: 0.2873
# Epoch 139/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8735 - loss: 0.3067 - val_accuracy: 0.8913 - val_loss: 0.2868
# Epoch 140/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3062 - val_accuracy: 0.9000 - val_loss: 0.2875
# Epoch 141/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3061 - val_accuracy: 0.8957 - val_loss: 0.2873
# Epoch 142/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.3057 - val_accuracy: 0.9000 - val_loss: 0.2881
# Epoch 143/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3055 - val_accuracy: 0.8957 - val_loss: 0.2869
# Epoch 144/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3053 - val_accuracy: 0.9000 - val_loss: 0.2877
# Epoch 145/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3049 - val_accuracy: 0.8957 - val_loss: 0.2887
# Epoch 146/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3047 - val_accuracy: 0.8957 - val_loss: 0.2872
# Epoch 147/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3046 - val_accuracy: 0.8957 - val_loss: 0.2885
# Epoch 148/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3043 - val_accuracy: 0.8957 - val_loss: 0.2868
# Epoch 149/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.3044 - val_accuracy: 0.8913 - val_loss: 0.2893
# Epoch 150/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3039 - val_accuracy: 0.8957 - val_loss: 0.2862
# Epoch 151/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3040 - val_accuracy: 0.8957 - val_loss: 0.2857
# Epoch 152/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3032 - val_accuracy: 0.8913 - val_loss: 0.2892
# Epoch 153/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.3032 - val_accuracy: 0.8870 - val_loss: 0.2894
# Epoch 154/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.3028 - val_accuracy: 0.8913 - val_loss: 0.2874
# Epoch 155/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3025 - val_accuracy: 0.8957 - val_loss: 0.2864
# Epoch 156/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3021 - val_accuracy: 0.8870 - val_loss: 0.2886
# Epoch 157/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.3019 - val_accuracy: 0.8870 - val_loss: 0.2874
# Epoch 158/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.3015 - val_accuracy: 0.8913 - val_loss: 0.2882
# Epoch 159/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3014 - val_accuracy: 0.8870 - val_loss: 0.2886
# Epoch 160/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3012 - val_accuracy: 0.8913 - val_loss: 0.2877
# Epoch 161/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.3009 - val_accuracy: 0.8870 - val_loss: 0.2881
# Epoch 162/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.3006 - val_accuracy: 0.8913 - val_loss: 0.2880
# Epoch 163/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3007 - val_accuracy: 0.8913 - val_loss: 0.2874
# Epoch 164/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.3002 - val_accuracy: 0.8913 - val_loss: 0.2892
# Epoch 165/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2999 - val_accuracy: 0.8913 - val_loss: 0.2888
# Epoch 166/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.3005 - val_accuracy: 0.8913 - val_loss: 0.2870
# Epoch 167/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2994 - val_accuracy: 0.8913 - val_loss: 0.2891
# Epoch 168/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2994 - val_accuracy: 0.8913 - val_loss: 0.2886
# Epoch 169/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2991 - val_accuracy: 0.8957 - val_loss: 0.2895
# Epoch 170/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2992 - val_accuracy: 0.8870 - val_loss: 0.2876
# Epoch 171/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2988 - val_accuracy: 0.8957 - val_loss: 0.2900
# Epoch 172/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2985 - val_accuracy: 0.8913 - val_loss: 0.2884
# Epoch 173/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2983 - val_accuracy: 0.8957 - val_loss: 0.2894
# Epoch 174/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2985 - val_accuracy: 0.8913 - val_loss: 0.2872
# Epoch 175/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2979 - val_accuracy: 0.8957 - val_loss: 0.2895
# Epoch 176/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2977 - val_accuracy: 0.8957 - val_loss: 0.2892
# Epoch 177/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2974 - val_accuracy: 0.8957 - val_loss: 0.2896
# Epoch 178/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8765 - loss: 0.2974 - val_accuracy: 0.8913 - val_loss: 0.2878
# Epoch 179/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8765 - loss: 0.2969 - val_accuracy: 0.8957 - val_loss: 0.2892
# Epoch 180/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2967 - val_accuracy: 0.8957 - val_loss: 0.2887
# Epoch 181/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2966 - val_accuracy: 0.8957 - val_loss: 0.2888
# Epoch 182/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2963 - val_accuracy: 0.8957 - val_loss: 0.2886
# Epoch 183/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2960 - val_accuracy: 0.8957 - val_loss: 0.2885
# Epoch 184/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2959 - val_accuracy: 0.8957 - val_loss: 0.2905
# Epoch 185/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2957 - val_accuracy: 0.8957 - val_loss: 0.2891
# Epoch 186/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2957 - val_accuracy: 0.8957 - val_loss: 0.2907
# Epoch 187/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2950 - val_accuracy: 0.9000 - val_loss: 0.2888
# Epoch 188/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2950 - val_accuracy: 0.8957 - val_loss: 0.2887
# Epoch 189/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2947 - val_accuracy: 0.9000 - val_loss: 0.2888
# Epoch 190/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2949 - val_accuracy: 0.8957 - val_loss: 0.2917
# Epoch 191/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2942 - val_accuracy: 0.8957 - val_loss: 0.2901
# Epoch 192/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2941 - val_accuracy: 0.8957 - val_loss: 0.2897
# Epoch 193/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2940 - val_accuracy: 0.8957 - val_loss: 0.2899
# Epoch 194/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2940 - val_accuracy: 0.9000 - val_loss: 0.2899
# Epoch 195/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2935 - val_accuracy: 0.8957 - val_loss: 0.2898
# Epoch 196/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2932 - val_accuracy: 0.9000 - val_loss: 0.2894
# Epoch 197/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2931 - val_accuracy: 0.9000 - val_loss: 0.2895
# Epoch 198/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2930 - val_accuracy: 0.9000 - val_loss: 0.2886
# Epoch 199/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2927 - val_accuracy: 0.8957 - val_loss: 0.2913
# Epoch 200/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2924 - val_accuracy: 0.9000 - val_loss: 0.2900
# Epoch 201/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2924 - val_accuracy: 0.8957 - val_loss: 0.2910
# Epoch 202/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2921 - val_accuracy: 0.9000 - val_loss: 0.2898
# Epoch 203/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2918 - val_accuracy: 0.9000 - val_loss: 0.2903
# Epoch 204/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2915 - val_accuracy: 0.9000 - val_loss: 0.2900
# Epoch 205/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2916 - val_accuracy: 0.8957 - val_loss: 0.2912
# Epoch 206/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2915 - val_accuracy: 0.9000 - val_loss: 0.2885
# Epoch 207/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2908 - val_accuracy: 0.9000 - val_loss: 0.2909
# Epoch 208/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2908 - val_accuracy: 0.9000 - val_loss: 0.2916
# Epoch 209/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2904 - val_accuracy: 0.9000 - val_loss: 0.2912
# Epoch 210/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2904 - val_accuracy: 0.9000 - val_loss: 0.2918
# Epoch 211/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2900 - val_accuracy: 0.9000 - val_loss: 0.2910
# Epoch 212/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2901 - val_accuracy: 0.9000 - val_loss: 0.2898
# Epoch 213/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2897 - val_accuracy: 0.9000 - val_loss: 0.2908
# Epoch 214/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2896 - val_accuracy: 0.9000 - val_loss: 0.2922
# Epoch 215/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2892 - val_accuracy: 0.9000 - val_loss: 0.2908
# Epoch 216/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2891 - val_accuracy: 0.9000 - val_loss: 0.2915
# Epoch 217/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2892 - val_accuracy: 0.9000 - val_loss: 0.2897
# Epoch 218/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8779 - loss: 0.2886 - val_accuracy: 0.9000 - val_loss: 0.2917
# Epoch 219/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2885 - val_accuracy: 0.9000 - val_loss: 0.2923
# Epoch 220/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2889 - val_accuracy: 0.9000 - val_loss: 0.2903
# Epoch 221/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2881 - val_accuracy: 0.9000 - val_loss: 0.2933
# Epoch 222/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2883 - val_accuracy: 0.9000 - val_loss: 0.2906
# Epoch 223/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2881 - val_accuracy: 0.9000 - val_loss: 0.2931
# Epoch 224/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2876 - val_accuracy: 0.9000 - val_loss: 0.2913
# Epoch 225/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2875 - val_accuracy: 0.9000 - val_loss: 0.2912
# Epoch 226/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2874 - val_accuracy: 0.9000 - val_loss: 0.2930
# Epoch 227/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2871 - val_accuracy: 0.9000 - val_loss: 0.2917
# Epoch 228/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2871 - val_accuracy: 0.9000 - val_loss: 0.2917
# Epoch 229/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2867 - val_accuracy: 0.9000 - val_loss: 0.2931
# Epoch 230/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2865 - val_accuracy: 0.9000 - val_loss: 0.2927
# Epoch 231/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2863 - val_accuracy: 0.9000 - val_loss: 0.2920
# Epoch 232/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2866 - val_accuracy: 0.9000 - val_loss: 0.2919
# Epoch 233/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2861 - val_accuracy: 0.9000 - val_loss: 0.2942
# Epoch 234/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2861 - val_accuracy: 0.9000 - val_loss: 0.2920
# Epoch 235/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2855 - val_accuracy: 0.9000 - val_loss: 0.2931
# Epoch 236/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2854 - val_accuracy: 0.9000 - val_loss: 0.2935
# Epoch 237/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2854 - val_accuracy: 0.9000 - val_loss: 0.2938
# Epoch 238/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2852 - val_accuracy: 0.9000 - val_loss: 0.2922
# Epoch 239/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2852 - val_accuracy: 0.9000 - val_loss: 0.2938
# Epoch 240/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2846 - val_accuracy: 0.9000 - val_loss: 0.2936
# Epoch 241/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2844 - val_accuracy: 0.9000 - val_loss: 0.2919
# Epoch 242/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2842 - val_accuracy: 0.9000 - val_loss: 0.2931
# Epoch 243/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2844 - val_accuracy: 0.9000 - val_loss: 0.2938
# Epoch 244/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2842 - val_accuracy: 0.9000 - val_loss: 0.2919
# Epoch 245/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2841 - val_accuracy: 0.9000 - val_loss: 0.2920
# Epoch 246/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2835 - val_accuracy: 0.9000 - val_loss: 0.2933
# Epoch 247/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2844 - val_accuracy: 0.9000 - val_loss: 0.2970
# Epoch 248/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2838 - val_accuracy: 0.9000 - val_loss: 0.2910
# Epoch 249/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2831 - val_accuracy: 0.9000 - val_loss: 0.2937
# Epoch 250/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2830 - val_accuracy: 0.9000 - val_loss: 0.2946
# Epoch 251/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2831 - val_accuracy: 0.9000 - val_loss: 0.2912
# Epoch 252/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2825 - val_accuracy: 0.9000 - val_loss: 0.2947
# Epoch 253/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2824 - val_accuracy: 0.9000 - val_loss: 0.2937
# Epoch 254/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2821 - val_accuracy: 0.9000 - val_loss: 0.2928
# Epoch 255/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2825 - val_accuracy: 0.9000 - val_loss: 0.2944
# Epoch 256/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2818 - val_accuracy: 0.9000 - val_loss: 0.2923
# Epoch 257/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2820 - val_accuracy: 0.9000 - val_loss: 0.2941
# Epoch 258/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2815 - val_accuracy: 0.9000 - val_loss: 0.2933
# Epoch 259/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8794 - loss: 0.2815 - val_accuracy: 0.9000 - val_loss: 0.2930
# Epoch 260/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2810 - val_accuracy: 0.9000 - val_loss: 0.2944
# Epoch 261/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2809 - val_accuracy: 0.9000 - val_loss: 0.2945
# Epoch 262/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2813 - val_accuracy: 0.9000 - val_loss: 0.2927
# Epoch 263/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2808 - val_accuracy: 0.9000 - val_loss: 0.2952
# Epoch 264/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2808 - val_accuracy: 0.9000 - val_loss: 0.2926
# Epoch 265/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2802 - val_accuracy: 0.9000 - val_loss: 0.2954
# Epoch 266/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2800 - val_accuracy: 0.9000 - val_loss: 0.2954
# Epoch 267/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2801 - val_accuracy: 0.9000 - val_loss: 0.2929
# Epoch 268/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2801 - val_accuracy: 0.9000 - val_loss: 0.2948
# Epoch 269/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2800 - val_accuracy: 0.9000 - val_loss: 0.2928
# Epoch 270/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2800 - val_accuracy: 0.9000 - val_loss: 0.2968
# Epoch 271/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2792 - val_accuracy: 0.9000 - val_loss: 0.2944
# Epoch 272/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2791 - val_accuracy: 0.9000 - val_loss: 0.2931
# Epoch 273/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2790 - val_accuracy: 0.9000 - val_loss: 0.2949
# Epoch 274/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2788 - val_accuracy: 0.9000 - val_loss: 0.2932
# Epoch 275/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8823 - loss: 0.2788 - val_accuracy: 0.9000 - val_loss: 0.2958
# Epoch 276/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2784 - val_accuracy: 0.9000 - val_loss: 0.2947
# Epoch 277/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2783 - val_accuracy: 0.9000 - val_loss: 0.2947
# Epoch 278/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2782 - val_accuracy: 0.9000 - val_loss: 0.2954
# Epoch 279/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2778 - val_accuracy: 0.9000 - val_loss: 0.2952
# Epoch 280/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8823 - loss: 0.2777 - val_accuracy: 0.9000 - val_loss: 0.2945
# Epoch 281/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2787 - val_accuracy: 0.9000 - val_loss: 0.2936
# Epoch 282/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2780 - val_accuracy: 0.9000 - val_loss: 0.2993
# Epoch 283/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8808 - loss: 0.2780 - val_accuracy: 0.9000 - val_loss: 0.2956
# Epoch 284/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2771 - val_accuracy: 0.9000 - val_loss: 0.2963
# Epoch 285/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8837 - loss: 0.2772 - val_accuracy: 0.9000 - val_loss: 0.2966
# Epoch 286/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2769 - val_accuracy: 0.9000 - val_loss: 0.2966
# Epoch 287/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2766 - val_accuracy: 0.9000 - val_loss: 0.2940
# Epoch 288/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2764 - val_accuracy: 0.9000 - val_loss: 0.2960
# Epoch 289/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2764 - val_accuracy: 0.9000 - val_loss: 0.2942
# Epoch 290/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2763 - val_accuracy: 0.9000 - val_loss: 0.2979
# Epoch 291/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2763 - val_accuracy: 0.9000 - val_loss: 0.2956
# Epoch 292/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2757 - val_accuracy: 0.9000 - val_loss: 0.2962
# Epoch 293/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2755 - val_accuracy: 0.9000 - val_loss: 0.2971
# Epoch 294/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8823 - loss: 0.2755 - val_accuracy: 0.9000 - val_loss: 0.2956
# Epoch 295/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2752 - val_accuracy: 0.9000 - val_loss: 0.2964
# Epoch 296/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2751 - val_accuracy: 0.9000 - val_loss: 0.2958
# Epoch 297/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2749 - val_accuracy: 0.9000 - val_loss: 0.2973
# Epoch 298/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2747 - val_accuracy: 0.9000 - val_loss: 0.2975
# Epoch 299/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2747 - val_accuracy: 0.9000 - val_loss: 0.2962
# Epoch 300/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2746 - val_accuracy: 0.9000 - val_loss: 0.2974
# Epoch 301/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2741 - val_accuracy: 0.9000 - val_loss: 0.2967
# Epoch 302/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2744 - val_accuracy: 0.9000 - val_loss: 0.2950
# Epoch 303/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2739 - val_accuracy: 0.9000 - val_loss: 0.2973
# Epoch 304/1000
# 23/23 - 0s - 6ms/step - accuracy: 0.8866 - loss: 0.2739 - val_accuracy: 0.9000 - val_loss: 0.2981
# Epoch 305/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8866 - loss: 0.2735 - val_accuracy: 0.9000 - val_loss: 0.2973
# Epoch 306/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2734 - val_accuracy: 0.9000 - val_loss: 0.2971
# Epoch 307/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8866 - loss: 0.2734 - val_accuracy: 0.9000 - val_loss: 0.2974
# Epoch 308/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8837 - loss: 0.2738 - val_accuracy: 0.9000 - val_loss: 0.2993
# Epoch 309/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2727 - val_accuracy: 0.9043 - val_loss: 0.2958
# Epoch 310/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2727 - val_accuracy: 0.9043 - val_loss: 0.2960
# Epoch 311/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2728 - val_accuracy: 0.9000 - val_loss: 0.2974
# Epoch 312/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2728 - val_accuracy: 0.9000 - val_loss: 0.2981
# Epoch 313/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2725 - val_accuracy: 0.9000 - val_loss: 0.2973
# Epoch 314/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2723 - val_accuracy: 0.9000 - val_loss: 0.2973
# Epoch 315/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2723 - val_accuracy: 0.9000 - val_loss: 0.2994
# Epoch 316/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2719 - val_accuracy: 0.9000 - val_loss: 0.2969
# Epoch 317/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2716 - val_accuracy: 0.9000 - val_loss: 0.2978
# Epoch 318/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2715 - val_accuracy: 0.9000 - val_loss: 0.2975
# Epoch 319/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2715 - val_accuracy: 0.9043 - val_loss: 0.2973
# Epoch 320/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2711 - val_accuracy: 0.9000 - val_loss: 0.2987
# Epoch 321/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2713 - val_accuracy: 0.9000 - val_loss: 0.2992
# Epoch 322/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2711 - val_accuracy: 0.9043 - val_loss: 0.2972
# Epoch 323/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2708 - val_accuracy: 0.9043 - val_loss: 0.2987
# Epoch 324/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2706 - val_accuracy: 0.9000 - val_loss: 0.2991
# Epoch 325/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2705 - val_accuracy: 0.9043 - val_loss: 0.2986
# Epoch 326/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.2704 - val_accuracy: 0.9000 - val_loss: 0.2992
# Epoch 327/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2704 - val_accuracy: 0.9043 - val_loss: 0.2982
# Epoch 328/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2700 - val_accuracy: 0.9043 - val_loss: 0.2991
# Epoch 329/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2699 - val_accuracy: 0.9043 - val_loss: 0.2990
# Epoch 330/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2697 - val_accuracy: 0.9043 - val_loss: 0.2985
# Epoch 331/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2696 - val_accuracy: 0.9043 - val_loss: 0.2985
# Epoch 332/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2696 - val_accuracy: 0.9000 - val_loss: 0.3009
# Epoch 333/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2693 - val_accuracy: 0.9043 - val_loss: 0.3003
# Epoch 334/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2692 - val_accuracy: 0.9043 - val_loss: 0.2983
# Epoch 335/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2691 - val_accuracy: 0.9043 - val_loss: 0.2990
# Epoch 336/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2687 - val_accuracy: 0.9043 - val_loss: 0.2995
# Epoch 337/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8866 - loss: 0.2691 - val_accuracy: 0.9000 - val_loss: 0.3013
# Epoch 338/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2686 - val_accuracy: 0.9043 - val_loss: 0.2989
# Epoch 339/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2685 - val_accuracy: 0.9043 - val_loss: 0.2983
# Epoch 340/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2683 - val_accuracy: 0.9043 - val_loss: 0.2990
# Epoch 341/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2683 - val_accuracy: 0.9043 - val_loss: 0.2990
# Epoch 342/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2682 - val_accuracy: 0.9043 - val_loss: 0.3011
# Epoch 343/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2679 - val_accuracy: 0.9043 - val_loss: 0.3005
# Epoch 344/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2678 - val_accuracy: 0.9043 - val_loss: 0.3012
# Epoch 345/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2677 - val_accuracy: 0.9043 - val_loss: 0.2988
# Epoch 346/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2677 - val_accuracy: 0.9043 - val_loss: 0.2993
# Epoch 347/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2672 - val_accuracy: 0.9043 - val_loss: 0.3016
# Epoch 348/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2672 - val_accuracy: 0.9043 - val_loss: 0.3005
# Epoch 349/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2673 - val_accuracy: 0.9043 - val_loss: 0.3025
# Epoch 350/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2665 - val_accuracy: 0.9043 - val_loss: 0.3002
# Epoch 351/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2666 - val_accuracy: 0.9043 - val_loss: 0.3005
# Epoch 352/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8910 - loss: 0.2666 - val_accuracy: 0.9043 - val_loss: 0.2996
# Epoch 353/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2665 - val_accuracy: 0.9043 - val_loss: 0.3020
# Epoch 354/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8881 - loss: 0.2663 - val_accuracy: 0.9043 - val_loss: 0.3019
# Epoch 355/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2675 - val_accuracy: 0.9043 - val_loss: 0.2975
# Epoch 356/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2659 - val_accuracy: 0.9043 - val_loss: 0.3024
# Epoch 357/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2657 - val_accuracy: 0.9043 - val_loss: 0.3014
# Epoch 358/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8895 - loss: 0.2655 - val_accuracy: 0.9043 - val_loss: 0.3017
# Epoch 359/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8910 - loss: 0.2655 - val_accuracy: 0.9043 - val_loss: 0.3005
# Epoch 360/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8910 - loss: 0.2653 - val_accuracy: 0.9043 - val_loss: 0.3012
# Epoch 361/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2654 - val_accuracy: 0.9043 - val_loss: 0.3007
# Epoch 362/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2648 - val_accuracy: 0.9043 - val_loss: 0.3019
# Epoch 363/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2648 - val_accuracy: 0.9043 - val_loss: 0.3015
# Epoch 364/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2646 - val_accuracy: 0.9043 - val_loss: 0.3025
# Epoch 365/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2647 - val_accuracy: 0.9043 - val_loss: 0.3018
# Epoch 366/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2646 - val_accuracy: 0.9043 - val_loss: 0.3037
# Epoch 367/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2645 - val_accuracy: 0.9043 - val_loss: 0.3027
# Epoch 368/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2643 - val_accuracy: 0.9043 - val_loss: 0.3015
# Epoch 369/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8910 - loss: 0.2641 - val_accuracy: 0.9043 - val_loss: 0.3036
# Epoch 370/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2637 - val_accuracy: 0.9043 - val_loss: 0.3016
# Epoch 371/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2638 - val_accuracy: 0.9043 - val_loss: 0.3020
# Epoch 372/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2633 - val_accuracy: 0.9043 - val_loss: 0.3043
# Epoch 373/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8910 - loss: 0.2639 - val_accuracy: 0.9043 - val_loss: 0.3053
# Epoch 374/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8910 - loss: 0.2630 - val_accuracy: 0.9043 - val_loss: 0.3023
# Epoch 375/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2633 - val_accuracy: 0.9043 - val_loss: 0.3028
# Epoch 376/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2628 - val_accuracy: 0.9043 - val_loss: 0.3033
# Epoch 377/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2626 - val_accuracy: 0.9043 - val_loss: 0.3031
# Epoch 378/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2630 - val_accuracy: 0.9043 - val_loss: 0.3051
# Epoch 379/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2629 - val_accuracy: 0.9043 - val_loss: 0.3016
# Epoch 380/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8924 - loss: 0.2624 - val_accuracy: 0.9043 - val_loss: 0.3024
# Epoch 381/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8910 - loss: 0.2623 - val_accuracy: 0.9043 - val_loss: 0.3052
# Epoch 382/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2618 - val_accuracy: 0.9043 - val_loss: 0.3043
# Epoch 383/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2619 - val_accuracy: 0.9043 - val_loss: 0.3041
# Epoch 384/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2618 - val_accuracy: 0.9043 - val_loss: 0.3027
# Epoch 385/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2615 - val_accuracy: 0.9043 - val_loss: 0.3039
# Epoch 386/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2612 - val_accuracy: 0.9043 - val_loss: 0.3045
# Epoch 387/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8939 - loss: 0.2612 - val_accuracy: 0.9043 - val_loss: 0.3048
# Epoch 388/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2614 - val_accuracy: 0.9043 - val_loss: 0.3019
# Epoch 389/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2614 - val_accuracy: 0.9043 - val_loss: 0.3069
# Epoch 390/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2605 - val_accuracy: 0.9043 - val_loss: 0.3040
# Epoch 391/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2606 - val_accuracy: 0.9043 - val_loss: 0.3046
# Epoch 392/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2605 - val_accuracy: 0.9043 - val_loss: 0.3036
# Epoch 393/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2604 - val_accuracy: 0.9043 - val_loss: 0.3055
# Epoch 394/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2601 - val_accuracy: 0.9043 - val_loss: 0.3057
# Epoch 395/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2599 - val_accuracy: 0.9043 - val_loss: 0.3042
# Epoch 396/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2600 - val_accuracy: 0.9043 - val_loss: 0.3032
# Epoch 397/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2596 - val_accuracy: 0.9043 - val_loss: 0.3050
# Epoch 398/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2594 - val_accuracy: 0.9043 - val_loss: 0.3047
# Epoch 399/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2595 - val_accuracy: 0.9043 - val_loss: 0.3059
# Epoch 400/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2594 - val_accuracy: 0.9043 - val_loss: 0.3055
# Epoch 401/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2589 - val_accuracy: 0.9043 - val_loss: 0.3053
# Epoch 402/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2588 - val_accuracy: 0.9043 - val_loss: 0.3061
# Epoch 403/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2588 - val_accuracy: 0.9043 - val_loss: 0.3048
# Epoch 404/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2587 - val_accuracy: 0.9043 - val_loss: 0.3051
# Epoch 405/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.8953 - loss: 0.2587 - val_accuracy: 0.9043 - val_loss: 0.3068
# Epoch 406/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2582 - val_accuracy: 0.9043 - val_loss: 0.3053
# Epoch 407/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2582 - val_accuracy: 0.9043 - val_loss: 0.3052
# Epoch 408/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2579 - val_accuracy: 0.9043 - val_loss: 0.3052
# Epoch 409/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2581 - val_accuracy: 0.9043 - val_loss: 0.3058
# Epoch 410/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2575 - val_accuracy: 0.9043 - val_loss: 0.3053
# Epoch 411/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2575 - val_accuracy: 0.9043 - val_loss: 0.3057
# Epoch 412/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2572 - val_accuracy: 0.9043 - val_loss: 0.3059
# Epoch 413/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2576 - val_accuracy: 0.9043 - val_loss: 0.3068
# Epoch 414/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2572 - val_accuracy: 0.9043 - val_loss: 0.3058
# Epoch 415/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2570 - val_accuracy: 0.9043 - val_loss: 0.3069
# Epoch 416/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2567 - val_accuracy: 0.9043 - val_loss: 0.3072
# Epoch 417/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2566 - val_accuracy: 0.9043 - val_loss: 0.3071
# Epoch 418/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2565 - val_accuracy: 0.9043 - val_loss: 0.3076
# Epoch 419/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2563 - val_accuracy: 0.9043 - val_loss: 0.3071
# Epoch 420/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8953 - loss: 0.2562 - val_accuracy: 0.9043 - val_loss: 0.3053
# Epoch 421/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8939 - loss: 0.2563 - val_accuracy: 0.9043 - val_loss: 0.3074
# Epoch 422/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8983 - loss: 0.2557 - val_accuracy: 0.9043 - val_loss: 0.3073
# Epoch 423/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2558 - val_accuracy: 0.9043 - val_loss: 0.3081
# Epoch 424/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8983 - loss: 0.2556 - val_accuracy: 0.9043 - val_loss: 0.3067
# Epoch 425/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.8968 - loss: 0.2560 - val_accuracy: 0.9043 - val_loss: 0.3085
# Epoch 426/1000
# ...
# Epoch 860/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9201 - loss: 0.2042 - val_accuracy: 0.8913 - val_loss: 0.3544
# Epoch 861/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2045 - val_accuracy: 0.8913 - val_loss: 0.3530
# Epoch 862/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2045 - val_accuracy: 0.8913 - val_loss: 0.3576
# Epoch 863/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9201 - loss: 0.2041 - val_accuracy: 0.8913 - val_loss: 0.3534
# Epoch 864/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.2055 - val_accuracy: 0.8957 - val_loss: 0.3522
# Epoch 865/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2045 - val_accuracy: 0.8913 - val_loss: 0.3579
# Epoch 866/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2041 - val_accuracy: 0.8913 - val_loss: 0.3549
# Epoch 867/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2039 - val_accuracy: 0.8913 - val_loss: 0.3545
# Epoch 868/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2037 - val_accuracy: 0.8913 - val_loss: 0.3557
# Epoch 869/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2038 - val_accuracy: 0.8913 - val_loss: 0.3551
# Epoch 870/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9201 - loss: 0.2035 - val_accuracy: 0.8913 - val_loss: 0.3566
# Epoch 871/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2031 - val_accuracy: 0.8913 - val_loss: 0.3573
# Epoch 872/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2032 - val_accuracy: 0.8913 - val_loss: 0.3549
# Epoch 873/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2036 - val_accuracy: 0.8913 - val_loss: 0.3557
# Epoch 874/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2032 - val_accuracy: 0.8913 - val_loss: 0.3574
# Epoch 875/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2031 - val_accuracy: 0.8957 - val_loss: 0.3537
# Epoch 876/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.2030 - val_accuracy: 0.8913 - val_loss: 0.3582
# Epoch 877/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2027 - val_accuracy: 0.8913 - val_loss: 0.3577
# Epoch 878/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2028 - val_accuracy: 0.8913 - val_loss: 0.3593
# Epoch 879/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2024 - val_accuracy: 0.8913 - val_loss: 0.3553
# Epoch 880/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2027 - val_accuracy: 0.8913 - val_loss: 0.3578
# Epoch 881/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.2030 - val_accuracy: 0.8913 - val_loss: 0.3565
# Epoch 882/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2022 - val_accuracy: 0.8913 - val_loss: 0.3576
# Epoch 883/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2020 - val_accuracy: 0.8913 - val_loss: 0.3588
# Epoch 884/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2019 - val_accuracy: 0.8957 - val_loss: 0.3579
# Epoch 885/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2019 - val_accuracy: 0.8913 - val_loss: 0.3578
# Epoch 886/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2019 - val_accuracy: 0.8957 - val_loss: 0.3574
# Epoch 887/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2017 - val_accuracy: 0.8957 - val_loss: 0.3577
# Epoch 888/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2018 - val_accuracy: 0.8957 - val_loss: 0.3578
# Epoch 889/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2016 - val_accuracy: 0.8957 - val_loss: 0.3598
# Epoch 890/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2016 - val_accuracy: 0.8913 - val_loss: 0.3600
# Epoch 891/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.9230 - loss: 0.2017 - val_accuracy: 0.8913 - val_loss: 0.3581
# Epoch 892/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2016 - val_accuracy: 0.8957 - val_loss: 0.3589
# Epoch 893/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2014 - val_accuracy: 0.8957 - val_loss: 0.3586
# Epoch 894/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2007 - val_accuracy: 0.8957 - val_loss: 0.3610
# Epoch 895/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2012 - val_accuracy: 0.8957 - val_loss: 0.3617
# Epoch 896/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.2012 - val_accuracy: 0.8957 - val_loss: 0.3562
# Epoch 897/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.2008 - val_accuracy: 0.8957 - val_loss: 0.3597
# Epoch 898/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2007 - val_accuracy: 0.8957 - val_loss: 0.3590
# Epoch 899/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2006 - val_accuracy: 0.8913 - val_loss: 0.3600
# Epoch 900/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.2005 - val_accuracy: 0.8957 - val_loss: 0.3602
# Epoch 901/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.2008 - val_accuracy: 0.8957 - val_loss: 0.3581
# Epoch 902/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2003 - val_accuracy: 0.8957 - val_loss: 0.3622
# Epoch 903/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2002 - val_accuracy: 0.8957 - val_loss: 0.3600
# Epoch 904/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2015 - val_accuracy: 0.8957 - val_loss: 0.3581
# Epoch 905/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9215 - loss: 0.2002 - val_accuracy: 0.8913 - val_loss: 0.3637
# Epoch 906/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2000 - val_accuracy: 0.8957 - val_loss: 0.3611
# Epoch 907/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.2001 - val_accuracy: 0.8957 - val_loss: 0.3602
# Epoch 908/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1999 - val_accuracy: 0.8957 - val_loss: 0.3628
# Epoch 909/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.2000 - val_accuracy: 0.8957 - val_loss: 0.3602
# Epoch 910/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.1996 - val_accuracy: 0.8957 - val_loss: 0.3609
# Epoch 911/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.1995 - val_accuracy: 0.8957 - val_loss: 0.3625
# Epoch 912/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1994 - val_accuracy: 0.8957 - val_loss: 0.3600
# Epoch 913/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.1992 - val_accuracy: 0.8957 - val_loss: 0.3604
# Epoch 914/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1994 - val_accuracy: 0.8957 - val_loss: 0.3639
# Epoch 915/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1990 - val_accuracy: 0.8957 - val_loss: 0.3629
# Epoch 916/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1990 - val_accuracy: 0.8957 - val_loss: 0.3608
# Epoch 917/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.1989 - val_accuracy: 0.8957 - val_loss: 0.3621
# Epoch 918/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1991 - val_accuracy: 0.8957 - val_loss: 0.3635
# Epoch 919/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1988 - val_accuracy: 0.8957 - val_loss: 0.3633
# Epoch 920/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1988 - val_accuracy: 0.8957 - val_loss: 0.3630
# Epoch 921/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1985 - val_accuracy: 0.8957 - val_loss: 0.3626
# Epoch 922/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1984 - val_accuracy: 0.8957 - val_loss: 0.3632
# Epoch 923/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1984 - val_accuracy: 0.8957 - val_loss: 0.3627
# Epoch 924/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.1981 - val_accuracy: 0.8957 - val_loss: 0.3634
# Epoch 925/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1977 - val_accuracy: 0.8957 - val_loss: 0.3646
# Epoch 926/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1981 - val_accuracy: 0.8957 - val_loss: 0.3660
# Epoch 927/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1977 - val_accuracy: 0.8957 - val_loss: 0.3623
# Epoch 928/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1976 - val_accuracy: 0.8957 - val_loss: 0.3645
# Epoch 929/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1977 - val_accuracy: 0.8957 - val_loss: 0.3656
# Epoch 930/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9230 - loss: 0.1981 - val_accuracy: 0.8957 - val_loss: 0.3644
# Epoch 931/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1975 - val_accuracy: 0.8957 - val_loss: 0.3635
# Epoch 932/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1977 - val_accuracy: 0.8957 - val_loss: 0.3645
# Epoch 933/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1974 - val_accuracy: 0.8957 - val_loss: 0.3662
# Epoch 934/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1974 - val_accuracy: 0.8957 - val_loss: 0.3641
# Epoch 935/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1972 - val_accuracy: 0.8957 - val_loss: 0.3651
# Epoch 936/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1970 - val_accuracy: 0.8957 - val_loss: 0.3650
# Epoch 937/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1974 - val_accuracy: 0.8957 - val_loss: 0.3645
# Epoch 938/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1969 - val_accuracy: 0.8957 - val_loss: 0.3640
# Epoch 939/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1966 - val_accuracy: 0.8957 - val_loss: 0.3654
# Epoch 940/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1966 - val_accuracy: 0.8957 - val_loss: 0.3645
# Epoch 941/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1963 - val_accuracy: 0.8957 - val_loss: 0.3679
# Epoch 942/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1963 - val_accuracy: 0.8957 - val_loss: 0.3670
# Epoch 943/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1966 - val_accuracy: 0.8957 - val_loss: 0.3668
# Epoch 944/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1963 - val_accuracy: 0.8957 - val_loss: 0.3672
# Epoch 945/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1962 - val_accuracy: 0.8957 - val_loss: 0.3663
# Epoch 946/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1963 - val_accuracy: 0.8957 - val_loss: 0.3662
# Epoch 947/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1958 - val_accuracy: 0.8957 - val_loss: 0.3694
# Epoch 948/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1957 - val_accuracy: 0.8957 - val_loss: 0.3665
# Epoch 949/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1959 - val_accuracy: 0.8957 - val_loss: 0.3692
# Epoch 950/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1960 - val_accuracy: 0.8957 - val_loss: 0.3690
# Epoch 951/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1962 - val_accuracy: 0.8957 - val_loss: 0.3673
# Epoch 952/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1959 - val_accuracy: 0.8957 - val_loss: 0.3683
# Epoch 953/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1951 - val_accuracy: 0.8957 - val_loss: 0.3670
# Epoch 954/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1955 - val_accuracy: 0.8957 - val_loss: 0.3692
# Epoch 955/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1950 - val_accuracy: 0.8957 - val_loss: 0.3666
# Epoch 956/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.9273 - loss: 0.1953 - val_accuracy: 0.8957 - val_loss: 0.3702
# Epoch 957/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.9244 - loss: 0.1950 - val_accuracy: 0.8957 - val_loss: 0.3689
# Epoch 958/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1950 - val_accuracy: 0.8957 - val_loss: 0.3687
# Epoch 959/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.9244 - loss: 0.1947 - val_accuracy: 0.8957 - val_loss: 0.3667
# Epoch 960/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1948 - val_accuracy: 0.8957 - val_loss: 0.3694
# Epoch 961/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.9273 - loss: 0.1947 - val_accuracy: 0.8957 - val_loss: 0.3686
# Epoch 962/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1943 - val_accuracy: 0.8957 - val_loss: 0.3702
# Epoch 963/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1942 - val_accuracy: 0.8957 - val_loss: 0.3691
# Epoch 964/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1943 - val_accuracy: 0.8957 - val_loss: 0.3704
# Epoch 965/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1945 - val_accuracy: 0.8957 - val_loss: 0.3719
# Epoch 966/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.9273 - loss: 0.1941 - val_accuracy: 0.8957 - val_loss: 0.3679
# Epoch 967/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1946 - val_accuracy: 0.8957 - val_loss: 0.3685
# Epoch 968/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9201 - loss: 0.1950 - val_accuracy: 0.8957 - val_loss: 0.3741
# Epoch 969/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1940 - val_accuracy: 0.8957 - val_loss: 0.3690
# Epoch 970/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1938 - val_accuracy: 0.8957 - val_loss: 0.3695
# Epoch 971/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1937 - val_accuracy: 0.8957 - val_loss: 0.3740
# Epoch 972/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1935 - val_accuracy: 0.8957 - val_loss: 0.3712
# Epoch 973/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1938 - val_accuracy: 0.8957 - val_loss: 0.3723
# Epoch 974/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1934 - val_accuracy: 0.8957 - val_loss: 0.3712
# Epoch 975/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1936 - val_accuracy: 0.8957 - val_loss: 0.3716
# Epoch 976/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1937 - val_accuracy: 0.8957 - val_loss: 0.3722
# Epoch 977/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1930 - val_accuracy: 0.8957 - val_loss: 0.3701
# Epoch 978/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1930 - val_accuracy: 0.8957 - val_loss: 0.3728
# Epoch 979/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1934 - val_accuracy: 0.8957 - val_loss: 0.3746
# Epoch 980/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1933 - val_accuracy: 0.8957 - val_loss: 0.3753
# Epoch 981/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1926 - val_accuracy: 0.8957 - val_loss: 0.3718
# Epoch 982/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1928 - val_accuracy: 0.8957 - val_loss: 0.3729
# Epoch 983/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1923 - val_accuracy: 0.8957 - val_loss: 0.3737
# Epoch 984/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1922 - val_accuracy: 0.8957 - val_loss: 0.3729
# Epoch 985/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1923 - val_accuracy: 0.8957 - val_loss: 0.3746
# Epoch 986/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1926 - val_accuracy: 0.8957 - val_loss: 0.3758
# Epoch 987/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1922 - val_accuracy: 0.8957 - val_loss: 0.3732
# Epoch 988/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1920 - val_accuracy: 0.8957 - val_loss: 0.3734
# Epoch 989/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1917 - val_accuracy: 0.8957 - val_loss: 0.3753
# Epoch 990/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1918 - val_accuracy: 0.8957 - val_loss: 0.3736
# Epoch 991/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.9273 - loss: 0.1922 - val_accuracy: 0.8957 - val_loss: 0.3741
# Epoch 992/1000
# 23/23 - 0s - 5ms/step - accuracy: 0.9259 - loss: 0.1916 - val_accuracy: 0.8957 - val_loss: 0.3750
# Epoch 993/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1919 - val_accuracy: 0.8957 - val_loss: 0.3743
# Epoch 994/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9244 - loss: 0.1920 - val_accuracy: 0.8957 - val_loss: 0.3749
# Epoch 995/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1916 - val_accuracy: 0.8957 - val_loss: 0.3760
# Epoch 996/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1917 - val_accuracy: 0.8957 - val_loss: 0.3746
# Epoch 997/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1912 - val_accuracy: 0.8957 - val_loss: 0.3750
# Epoch 998/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9273 - loss: 0.1910 - val_accuracy: 0.8957 - val_loss: 0.3754
# Epoch 999/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1909 - val_accuracy: 0.8957 - val_loss: 0.3770
# Epoch 1000/1000
# 23/23 - 0s - 4ms/step - accuracy: 0.9259 - loss: 0.1910 - val_accuracy: 0.8957 - val_loss: 0.3744

# %% [markdown]
# <h3>With thousand iteration we can get %93 acc rate but we dont know that our data is overfitted to train data</br>
# </br>
# To learn it:</h3>

# %%
train_acc = our_model.history["accuracy"]
test_acc = our_model.history["val_accuracy"]

#first plot
plt.subplot(2,1,1)
plt.title("Train Accuracy")
plt.plot(train_acc)
ax1 = plt.gca()
ax1.set_facecolor('black') 
ax1.grid(True , color = "#A9A9A9")
#second plot
plt.subplot(2,1,2)
plt.title("Test Accuracy")
plt.plot(test_acc,color = "green")
ax2 = plt.gca()
ax2.set_facecolor('black') 
ax2.grid(True , color = "#A9A9A9")


plt.tight_layout()
plt.show()

# %% [markdown]
# <font color = "blue">
# <h4>
# If the train accuracy was increasing while the test accuracy was decreasing, we could have said that our model was overfitting. However, both graphs are quite similar, and as we can see, after approximately 100 epochs, there was almost no further improvement in the graph, which indicates that 1000 epochs would have been unnecessary.
#
# </h4>
# </font

# %% [markdown]
# ## Thank You for Reading!
#
# I sincerely appreciate your time and attention while going through this notebook. I hope you found the content helpful and insightful. If you have any questions or feedback, feel free to reach out!
#
# Happy learning and coding! 🚀
